# %%
# Libraries
## Mathematics
import numpy as np
from scipy.stats import norm
from scipy.interpolate import interp1d

## Visualization
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
# Load functions .py files
from Theoretical_boundaries_visualization_functions import optimal_stopping_Brownian_bridge, optimal_stopping_Normal
from Visualisation import OSB_visualisation
from Checking_simulated_boundary_functions_3 import optimal_stopping_montecarlo_3

# %% [markdown]
# # Exact optimal stopping boundary for a degenerated distribution

# %%
# Pinning point
r = 0

# Temporal mesh
mesh = 1000
t_mesh = np.linspace(0, 1, mesh)

# Boundary
exact_boundary_BB = optimal_stopping_Brownian_bridge(t_mesh, r)
L = 10000
np.random.seed(123)
value_function_BB, X_vals_BB = optimal_stopping_montecarlo_3(mu = "discrete", weights = np.array([1]), parameters = np.array([[r],[1]]), N = mesh, a = -1, b = 1, L = L, M = 4000, alpha = 2)

# Plotting
OSB_visualisation(N = mesh, value_function = value_function_BB, X_vals = X_vals_BB, title = f"Optimal stopping boundary for degenerated distribution in r={r}", name = "BB_MonteCarlo.png", exact_boundary = exact_boundary_BB)
# Out:
# Temporal grid point: 900
# Temporal grid point: 800
# Temporal grid point: 700
# Temporal grid point: 600
# Temporal grid point: 500
# Temporal grid point: 400
# Temporal grid point: 300
# Temporal grid point: 200
# Temporal grid point: 100

# %% [markdown]
# # Theoretical optimal stopping boundary for a Normal distribution with standard deviation lower than 1

# %% [markdown]
# ## Standard deviation of 1/2

# %%
# Normal distribution setup
mean = 0
sigma = 1/2

# Temporal mesh
mesh = 1000
t_mesh = np.linspace(0, 1, mesh)

# Boundary
exact_boundary_Normal = optimal_stopping_Normal(mesh=t_mesh, m=mean, gamma=sigma, tol=1e-6)
L = 10000
np.random.seed(123)
value_function_Normal, X_vals_Normal = optimal_stopping_montecarlo_3(mu="continuous", weights=np.array([1]), parameters=np.array([[mean], [sigma]]), N=mesh, a=-1.3, b=1.3, L=L, M=4000, alpha = 1.5)


# Plotting
OSB_visualisation(N = mesh, value_function = value_function_Normal, X_vals = X_vals_Normal, title = fr"Optimal stopping boundary for N({mean}, {sigma})", name = "Normal_MonteCarlo.png", exact_boundary = exact_boundary_Normal)
# Out:
# 0 1.0
# 100 5.1510349919503136e-05
# 200 6.944029380320232e-06
# 300 1.7147304646982898e-06
# Temporal grid point: 900
# Temporal grid point: 800
# Temporal grid point: 700
# Temporal grid point: 600
# Temporal grid point: 500
# Temporal grid point: 400
# Temporal grid point: 300
# Temporal grid point: 200
# Temporal grid point: 100

# %% [markdown]
# # Mixtures

# %% [markdown]
# ## Discrete mixture

# %%
# Temporal mesh
mesh = 1250
t_mesh = np.linspace(0, 1, mesh) # Temporal grid

# Spatial grid
L = 12500

# Boundary
np.random.seed(123)
value_function_Mixture1, X_vals_Mixture1 = optimal_stopping_montecarlo_3(mu = "discrete", weights = np.array([1/2, 1/2]), parameters = np.array([[-1, 1],[1/2, 1/2]]), N = mesh, a = -2, b = 2.5, L = L, M = 4500, alpha = 2)

# Plotting
OSB_visualisation(N = mesh, value_function = value_function_Mixture1, X_vals = X_vals_Mixture1, title = "Discrete mixture trial", name = "Mixture1_MonteCarlo.png", a = -1.5, b = 2.5)
# Out:
# Temporal grid point: 1200
# Temporal grid point: 1100
# Temporal grid point: 1000
# Temporal grid point: 900
# Temporal grid point: 800
# Temporal grid point: 700
# Temporal grid point: 600
# Temporal grid point: 500
# Temporal grid point: 400
# Temporal grid point: 300
# Temporal grid point: 200
# Temporal grid point: 100

# %% [markdown]
# ## Continuous mixture

# %%
# Temporal mesh
mesh = 1250
t_mesh = np.linspace(0, 1, mesh) # Temporal grid

# Spatial grid
L = 12500

# Boundary
np.random.seed(123)
value_function_Mixture2, X_vals_Mixture2 = optimal_stopping_montecarlo_3(mu = "continuous", weights = np.array([1/2, 1/2]), parameters = np.array([[-5/9, 5/9],[2/3, 2/3]]), N = mesh, a = -2.3, b = 2.3, L = L, M = 4500)

# Plotting
OSB_visualisation(N = mesh, value_function = value_function_Mixture2, X_vals = X_vals_Mixture2, title = "Continuous mixture trial", name = "Mixture2_MonteCarlo.png", a = -1, b = 1.5)
# Out:
# Temporal grid point: 1200
# Temporal grid point: 1100
# Temporal grid point: 1000
# Temporal grid point: 900
# Temporal grid point: 800
# Temporal grid point: 700
# Temporal grid point: 600
# Temporal grid point: 500
# Temporal grid point: 400
# Temporal grid point: 300
# Temporal grid point: 200
# Temporal grid point: 100

# %%
# Temporal mesh
mesh = 1250
t_mesh = np.linspace(0, 1, mesh) # Temporal grid

# Spatial grid
L = 12500

# Boundary
np.random.seed(123)
value_function_Mixture3, X_vals_Mixture3 = optimal_stopping_montecarlo_3(mu = "continuous", weights = np.array([1/4, 1/2, 1/4]), parameters = np.array([[-5/9, 0, 1],[2/3, 1/3, 1/2]]), N = mesh, a = -2.3, b = 2.3, L = L, M = 4500)

# Plotting
OSB_visualisation(N = mesh, value_function = value_function_Mixture3, X_vals = X_vals_Mixture3, title = "Mixture of three Gaussians", name = "Mixture3_MonteCarlo.png")
# Out:
# Temporal grid point: 1200
# Temporal grid point: 1100
# Temporal grid point: 1000
# Temporal grid point: 900
# Temporal grid point: 800
# Temporal grid point: 700
# Temporal grid point: 600
# Temporal grid point: 500
# Temporal grid point: 400
# Temporal grid point: 300
# Temporal grid point: 200
# Temporal grid point: 100
